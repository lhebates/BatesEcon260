# %% [markdown]
# a)
# \begin{align}
#     & \min_{q_1,q_2} \quad p_1 q_1 + p_2 q_2 \\
#     \text{s.t.}\quad & q_1^{0.4} q_2^{0.6} = \overline{U}
# \end{align}
#
# b)
# \begin{align}
#     L = p_1 q_1 + p_2 q_2 + \lambda(\overline{U}-q_1^{0.4} q_2^{0.6})
# \end{align}
#
# c)
# \begin{align}
#    \frac{\partial L}{\partial q_1} &= p_1 + {0.4}\lambda q_1^{-0.6}q_2^{0.6} = 0
# \end{align}
#
# \begin{align}
#    \frac{\partial L}{\partial q_2} &= p_2 + {0.6}\lambda q_1^{0.4}q_2^{-0.4} = 0
# \end{align}
#
# \begin{align}
#    \frac{\partial L}{\partial \lambda} &= \overline{U} - q_1^{0.4}q_2^{0.6} = 0
# \end{align}
#
# d)
# \begin{align}
#    p_1 &=  -{0.4}\lambda q_1^{-0.6}q_2^{0.6} \\
#    p_2 &=  -{0.6}\lambda q_1^{0.4}q_2^{-0.4} \\
# \end{align}
#
# \begin{align}
#    \frac{p_1}{p_2} &= \frac{0.4}{0.6}\frac{q_2}{q_1} \\
#    q_2 &= \frac{0.6}{0.4}\frac{p_1}{p_2}q_1 \\
#    q_1 &= \frac{0.4}{0.6}\frac{p_2}{p_1}q_2
# \end{align}
#
# Plug equation for $q_2$ into FOC for $\frac{\partial L}{\partial \lambda}$ found in part c
# \begin{align}
#    0&=\overline{U}-q_1^{0.4}\bigg(\frac{0.6}{0.4}\frac{p_1}{p_2}q_1\bigg)^{0.6} \\
#    \overline{U}&=q_1^{0.4}\bigg(\frac{0.6}{0.4}\frac{p_1}{p_2}q_1\bigg)^{0.6} \\
#    q^*_1&=\bigg(\frac{0.6}{0.4}\frac{p_1}{p_2}\bigg)^{-0.6}\overline{U}
# \end{align}
#
# Plug equation for $q_1$ into FOC for $\frac{\partial L}{\partial \lambda}$ found in part c
#
# \begin{align}
#    0&=\overline{U}-\bigg(\frac{0.4}{0.6}\frac{p_2}{p_1}q_2\bigg)^{0.4}q_2^{0.6} \\
#    \overline{U}&=\bigg(\frac{0.4}{0.6}\frac{p_2}{p_1}q_2\bigg)^{0.4}q_2^{0.6} \\
#    q^*_2&=\bigg(\frac{0.4}{0.6}\frac{p_2}{p_1}\bigg)^{-0.4}\overline{U}
# \end{align}
#
# e)
#
# $$C(q_1,q_2) = (p_1)(\bigg(\frac{0.6}{0.4}\frac{p_1}{p_2}\bigg)^{-0.6}\overline{U}) + (p_2)(\bigg(\frac{0.4}{0.6}\frac{p_2}{p_1}\bigg)^{-0.4}\overline{U})$$
#
# $$E(p_1,p_2,\overline{U}) = (\bigg(\frac{0.6}{0.4}\frac{p_1^2}{p_2}\bigg)^{-0.6}\overline{U}) + (\bigg(\frac{0.4}{0.6}\frac{p_2^2}{p_1}\bigg)^{-0.4}\overline{U})$$
#
# f)
#
# $$\frac{\partial q^*_1}{\partial p_1} = -0.6\bigg(\frac{3}{2}\frac{p_1}{p_2}\bigg)^{-1.6}\overline{U}$$
# $$\frac{\partial q^*_1}{\partial p_2} = -0.6\bigg(\frac{3}{2}\frac{p_1}{p_2}\bigg)^{-1.6}\overline{U}$$
# $$\frac{\partial q^*_1}{\partial \overline{U}} = \bigg(\frac{3}{2}\frac{p_1}{p_2}\bigg)^{-0.6}$$
#
# From this we can see as $p_1$ increases, H1 will increase, as $p_2$ increases H1 will decrease, and as $\overline{U}$ increases, there will be no change
#
#
# g)
#
# Shephard's lemma = $H_i(p_i,p_{-i},\overline{U}) = \frac{\partial E(p_i,p_{-i},\overline{U})}{\partial p_i}$ for i=1,2
#
# $$\frac{\partial E(p_1,p_2,\overline{U})}{\partial p_1} = 0.4\frac{1}{0.4}(\frac{p_1}{\frac{2}{5}})^{-0.6}(\frac{p_2}{\frac{3}{5}})^{0.6}\overline{U}$$
# $$ = (\frac{p_1}{0.4})^{-0.6}(\frac{p_2}{0.6})^{0.6}\overline{U}$$
#
# $$\frac{\partial E(p_1,p_2,\overline{U})}{\partial p_2} = 0.6\frac{1}{0.6}(\frac{p_1}{\frac{2}{5}})^{0.4}(\frac{p_2}{\frac{3}{5}})^{-0.4}\overline{U}$$
# $$ = (\frac{p_1}{0.4})^{0.4}(\frac{p_2}{0.6})^{-0.4}\overline{U}$$
#
#
# h)
#
# \begin{align}
# &(\frac{p_1}{0.4})^{-0.6}(\frac{p_2}{0.6})^{0.6}(\frac{0.4}{p1})^{0.4}(\frac{0.6}{p2})^{0.6}Y\\
# &= (\frac{p_1}{0.4})^{-0.6}(\frac{0.4}{p1})^{0.4}Y\\
# &= 0.4^{0.6}(p1)^{-0.6}(\frac{1}{p1})^{0.4}0.4^{0.4}Y\\
# &= 0.4(p1)^{-0.6}({p1})^{-0.4}Y\\
# &= \frac{2}{5}(\frac{Y}{P1})\\
# \end{align}
#
# The Hicksian demand is equal to D1$= \frac{2}{5}(\frac{Y}{P1})$
#
# $$H)  Required: U = V(p_1,p_2,Y) = (\frac{0.4}{p_1})^{0.4}(\frac{0.6}{p_2})^{0.6}$$
#
# $$ Expenditure function = E(p_1,p_2,U) = (\frac{p_1}{.4})^{0.4} (\frac{p_2}{.6})^{0.6} U$$
#
# $$Isolate: m = m 0.4^{0.4}p_1^{0.4}(1-0.4)^{1-.04}p_2^{0.4-1} = U $$
#
# $$\frac{U}{0.4^{0.4}(1-.4)^{1-.4}p_2.4^{1-.4}}$$
#
# $$U(\frac{p_1}{0.4})^{.4}(\frac{p_2}{1-.4}^{1-.4}$$
#
# The function is not equal to Y
